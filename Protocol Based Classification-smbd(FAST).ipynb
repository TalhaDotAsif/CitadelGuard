# %%
# Importing the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-88584eaf-2595-4614-9fe8-064841cbea38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88584eaf-2595-4614-9fe8-064841cbea38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving smbdInternal.csv to smbdInternal.csv

# %%
# Importing the dataset
dataset = pd.read_csv('smbdInternal.csv')

# %%
dataset.describe()
# Out:
#            src_port  dst_port  protocol  eventid
# count    324.000000     324.0     324.0    324.0
# mean   48703.027778     445.0       1.0      2.0
# std    16637.471489       0.0       0.0      0.0
# min     1235.000000     445.0       1.0      2.0
# 25%    50095.750000     445.0       1.0      2.0
# 50%    52041.500000     445.0       1.0      2.0
# 75%    59419.750000     445.0       1.0      2.0
# max    65366.000000     445.0       1.0      2.0

# %%
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   src_ip       324 non-null    object
#  1   dst_ip       324 non-null    object
#  2   src_port     324 non-null    int64
#  3   dst_port     324 non-null    int64
#  4   protocol     324 non-null    int64
#  5   timestamp    324 non-null    object
#  6   eventid      324 non-null    int64
#  7   ThreatLevel  324 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 20.4+ KB
#             src_ip      dst_ip  ...  eventid          ThreatLevel
# 0      2.61.137.35  172.28.0.2  ...        2  extremely malicious
# 1  112.135.210.172  172.28.0.2  ...        2  extremely malicious
# 2    103.48.24.122  172.28.0.2  ...        2  extremely malicious
# 3     193.56.29.54  172.28.0.2  ...        2  extremely malicious
# 4     193.56.29.41  172.28.0.2  ...        2  extremely malicious
#
# [5 rows x 8 columns]

# %%
# Splitting the dataset into the Training set and Test set
X = dataset.iloc[:, [2,3,4,6]].values
y = dataset.iloc[:, 7].values

# Splitting the dataset into the Training set and Test set
#XX = datasetemp.iloc[:, [2,3,6]].values
#yy = datasetemp.iloc[:, 4].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 100, solver='lbfgs', multi_class='auto', max_iter=76)
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-db244408e154> in <module>()
#       2 from sklearn.linear_model import LogisticRegression
#       3 classifier = LogisticRegression(random_state = 100, solver='lbfgs', multi_class='auto', max_iter=76)
# ----> 4 classifier.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1556                 " in the data, but the data contains only one"
#    1557                 " class: %r"
# -> 1558                 % classes_[0]
#    1559             )
#    1560
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 'extremely malicious'

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test1)

# %%
# Predict probabilities
probs_y=classifier.predict_proba(X_test1)

# %%
probs_y = np.round(probs_y, 2)

# %%
res = "{:<20} | {:<20} | {:<20} | {:<20} | {:<20}".format("y_test", "y_pred", "Extremely Malicious(%)", "Malicious(%)", "Slightly Malicious(%)\n")
res += "-"*65+"\n"
res += "\n".join("{:<20} | {:<20} | {:<20} | {:<20} | {:<20}".format(x, y, a, b, c) for x, y, a, b, c in zip(y_test1, y_pred, probs_y[:,0], probs_y[:,1], probs_y[:,2]))
res += "\n"+"-"*65+"\n"
print(res)

# %%
from sklearn.metrics import accuracy_score
print(y_pred[0])
print(y_test1[0])

print(accuracy_score(y_test1,y_pred))
