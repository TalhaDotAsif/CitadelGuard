# %%
# Importing the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-34723ed2-1e32-47bf-b8a9-42342145b537" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34723ed2-1e32-47bf-b8a9-42342145b537">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving external_normalized - external_normalized.csv to external_normalized - external_normalized.csv

# %%
# from google.colab import files
# uploaded=files.upload()

# %%
# Importing the dataset
dataset = pd.read_csv('external_normalized - external_normalized.csv')

# Importing temporary test dataset
# datasetemp = pd.read_csv('test.csv')

# %%
dataset.describe()
# Out:
#            src_port      dst_port      protocol       eventid
# count  21084.000000  21084.000000  21084.000000  21084.000000
# mean   24109.967369    450.773952      1.468649      4.868099
# std    26190.632749   2213.595076      2.728408      3.229099
# min        0.000000      0.000000      0.000000      1.000000
# 25%        0.000000      0.000000      0.000000      2.000000
# 50%     5819.000000     80.000000      0.000000      4.000000
# 75%    53013.000000    445.000000      1.000000      8.000000
# max    65531.000000  59841.000000     14.000000     18.000000

# %%
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21084 entries, 0 to 21083
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   src_ip       21084 non-null  object
#  1   dst_ip       13375 non-null  object
#  2   src_port     21084 non-null  int64
#  3   dst_port     21084 non-null  int64
#  4   protocol     21084 non-null  int64
#  5   timestamp    21084 non-null  object
#  6   eventid      21084 non-null  int64
#  7   ThreatLevel  21084 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 1.3+ MB
#           src_ip      dst_ip  src_port  ...  timestamp  eventid          ThreatLevel
# 0   185.53.91.46  172.28.0.2     59887  ...    33:05.2        1   slightly malicious
# 1   92.38.163.23  172.28.0.2     37697  ...    33:06.9        2            malicious
# 2   92.38.163.23  172.28.0.2     52925  ...    33:04.6        2  extremely malicious
# ...

# %%
# Splitting the dataset into the Training set and Test set
X = dataset.iloc[:, [2,3,4,6]].values
y = dataset.iloc[:, 7].values

# Splitting the dataset into the Training set and Test set
# XX = datasetemp.iloc[:, [2,3,6]].values
# yy = datasetemp.iloc[:, 4].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)
# X_train1, X_test1, y_train1, y_test1 = train_test_split(XX, yy, test_size = 0.30, random_state = 100)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 100, solver='lbfgs', multi_class='auto', max_iter=76)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=76, random_state=100)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Predict probabilities
probs_y=classifier.predict_proba(X_test)

# %%
probs_y = np.round(probs_y, 2)

# %%
res = "{:<20} | {:<20} | {:<20} | {:<20} | {:<20}".format("y_test", "y_pred", "Extremely Malicious(%)", "Malicious(%)", "Slightly Malicious(%)\n")
res += "-"*65+"\n"
res += "\n".join("{:<20} | {:<20} | {:<20} | {:<20} | {:<20}".format(x, y, a, b, c) for x, y, a, b, c in zip(y_test, y_pred, probs_y[:,0], probs_y[:,1], probs_y[:,2]))
res += "\n"+"-"*65+"\n"
print(res)
# Out:
# y_test               | y_pred               | Extremely Malicious(%) | Malicious(%)         | Slightly Malicious(%)
# -----------------------------------------------------------------
# extremely malicious  | extremely malicious  | 0.96                 | 0.0                  | 0.04
# extremely malicious  | extremely malicious  | 0.95                 | 0.0                  | 0.05
# extremely malicious  | extremely malicious  | 0.96                 | 0.0                  | 0.04
# extremely malicious  | extremely malicious  | 0.96                 | 0.0                  | 0.04
# extremely malicious  | extremely malicious  | 0.96                 | 0.0                  | 0.04
# extremely malicious  | extremely malicious  | 0.96                 | 0.0                  | 0.04
# extremely malicious  | extremely malicious  | 0.95                 | 0.0                  | 0.05
# slightly malicious   | extremely malicious  | 0.95                 | 0.0                  | 0.05
# ...

# %%
from sklearn.metrics import accuracy_score


print(accuracy_score(y_test,y_pred))
# Out:
# 0.9558963009800822
